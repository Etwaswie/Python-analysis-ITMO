# %%
import requests
import pandas as pd

# %% [markdown]
# Получить информацию обо всех книгах и сохранить в pd.DataFrame - 1 балл

# %%
api_base_url = 'https://anapioficeandfire.com/api/'

# %%
books_list = requests.get(f'{api_base_url}/books').json()

# %%
books = pd.DataFrame(books_list)
books.head()
# Out:
#                                          url               name  \
# 0  https://anapioficeandfire.com/api/books/1  A Game of Thrones
# 1  https://anapioficeandfire.com/api/books/2   A Clash of Kings
# 2  https://anapioficeandfire.com/api/books/3  A Storm of Swords
# 3  https://anapioficeandfire.com/api/books/4   The Hedge Knight
# 4  https://anapioficeandfire.com/api/books/5  A Feast for Crows
#
#              isbn                authors  numberOfPages  \
# 0  978-0553103540  [George R. R. Martin]            694
# 1  978-0553108033  [George R. R. Martin]            768
# 2  978-0553106633  [George R. R. Martin]            992
# 3  978-0976401100  [George R. R. Martin]            164
# 4  978-0553801507  [George R. R. Martin]            784
#
#                    publisher        country     mediaType  \
# 0               Bantam Books  United States     Hardcover
# 1               Bantam Books  United States      Hardback
# 2               Bantam Books  United States     Hardcover
# ...

# %% [markdown]
# Получить информацию обо всех домах Вестероса (Houses) и сохранить в pd.DataFrame - 1 балл

# %%
house_list = requests.get(f'{api_base_url}/houses').json()

# %%
houses = pd.DataFrame(house_list)
houses.head()
# Out:
#                                           url                         name  \
# 0  https://anapioficeandfire.com/api/houses/1                 House Algood
# 1  https://anapioficeandfire.com/api/houses/2  House Allyrion of Godsgrace
# 2  https://anapioficeandfire.com/api/houses/3                  House Amber
# 3  https://anapioficeandfire.com/api/houses/4                House Ambrose
# 4  https://anapioficeandfire.com/api/houses/5   House Appleton of Appleton
#
#             region                                         coatOfArms  \
# 0  The Westerlands  A golden wreath, on a blue field with a gold b...
# 1            Dorne          Gyronny Gules and Sable, a hand couped Or
# 2        The North
# 3        The Reach                             Or, semy of ants gules
# 4        The Reach  Or, an apple tree eradicated proper fructed gu...
#
#              words titles        seats  \
# 0                      []           []
# 1  No Foe May Pass     []  [Godsgrace]
# ...

# %% [markdown]
# Получить информацию обо всех домах Вестероса, у которых есть девиз, и сохранить в pd.DataFrame - 2 балла

# %%
params = {'hasTitles': True}

# %%
house_with_titles_list = requests.get(f'{api_base_url}/houses', params=params).json()

# %%
house_with_titles = pd.DataFrame(house_with_titles_list)
house_with_titles.head()
# Out:
#                                            url  \
# 0   https://anapioficeandfire.com/api/houses/7
# 1   https://anapioficeandfire.com/api/houses/8
# 2  https://anapioficeandfire.com/api/houses/10
# 3  https://anapioficeandfire.com/api/houses/13
# 4  https://anapioficeandfire.com/api/houses/14
#
#                              name           region  \
# 0        House Arryn of the Eyrie         The Vale
# 1        House Ashford of Ashford        The Reach
# 2      House Baelish of Harrenhal   The Riverlands
# 3      House Banefort of Banefort  The Westerlands
# 4  House Bar Emmon of Sharp Point   The Crownlands
#
#                                           coatOfArms                  words  \
# 0  A sky-blue falcon soaring against a white moon...       As High as Honor
# 1  Tenny, a sun in splendour beneath a chevron in...  Our Sun Shines Bright
# 2  A field of silver mockingbirds, on a green fie...
# 3  A black hooded man, on a grey field, within a ...
# ...

# %% [markdown]
# Установить библиотеку psycopg2

# %%
# !pip install psycopg2-binary

# %%
import psycopg2

# %% [markdown]
# Подключиться к БД - 1 балл

# %%
Hostname = 'hh-pgsql-public.ebi.ac.uk'
Port = 5432
Database = 'pfmegrnargs'
User = 'reader'
Password = 'NWDMCE5xdipIjRrp'

# %%
try:
    conn = psycopg2.connect(dbname=Database, user=User, password=Password, host=Hostname)
except:
    print('Can`t establish connection to database')

# %% [markdown]
# Получите 10 строк из таблицы rnc_database - 2 балла

# %%
with conn.cursor() as cursor:
    cursor.execute('SELECT * FROM rnc_database limit 10')
    rna_10 = cursor.fetchall()
cursor.close()

# %%
rna_10[0]
# Out:
# (1,
#  datetime.datetime(2017, 5, 1, 0, 0),
#  'RNACEN',
#  'ENA',
#  884,
#  'ENA',
#  'Y',
#  ' ',
#  'ENA',
#  '',
#  412,
#  10,
#  900074,
#  12086180,
#  814855,
#  "provides a comprehensive record of the world's nucleotide sequencing information",
#  'https://www.ebi.ac.uk/ena/browser/',
#  [{'upi': 'URS00002D0E0C', 'taxid': 10090},
#   {'upi': 'URS000035EE7E', 'taxid': 9606},
#   {'upi': 'URS0000000001', 'taxid': 77133}],
#  [{'title': 'The European Nucleotide Archive in 2017',
#    'authors': 'Silvester et al.',
#    'journal': 'Nucleic Acids Res. 2017',
#    'pubmed_id': '29140475'}])

# %% [markdown]
# Получу названия столбцов и преобразую в нормальный вид:

# %%
with conn.cursor() as cursor:
    cursor.execute("select Column_name from INFORMATION_SCHEMA.COLUMNS where TABLE_NAME='rnc_database'")
    columns = cursor.fetchall()
cursor.close()

# %%
for i in range(len(columns)):
  columns[i] = columns[i][0]

# %%
pd.DataFrame(rna_10, columns=columns).head()
# Out:
#    id                  timestamp userstamp      descr  current_release  \
# 0   1 2017-05-01 00:00:00.000000    RNACEN        ENA              884
# 1   5 2017-05-17 00:00:00.000000    RNACEN       VEGA               98
# 2  26 2017-05-01 00:00:00.000000    RNACEN    GENCODE              450
# 3  55 2023-10-10 15:02:45.191606    RNACEN     MGNIFY              839
# 4  41 2017-05-01 00:00:00.000000    RNACEN  GENECARDS              867
#
#   full_descr alive for_release display_name project_id  avg_length  \
# 0        ENA     Y                      ENA                  412.0
# 1       VEGA     N                     VEGA  PRJEB4568         NaN
# 2    GENCODE     N                  GENCODE                  889.0
# 3     MGnify     Y        None       MGnify       None       151.0
# 4  MalaCards     Y                GeneCards                 1298.0
#
#    min_length  max_length  num_sequences  num_organisms  \
# 0        10.0    900074.0       12086180         814855
# ...

# %% [markdown]
# Получите значения столбцов display_name, num_sequences, num_organisms, , url для 10 строк из таблицы rnc_database - 2 балла

# %%
with conn.cursor() as cursor:
    cursor.execute('SELECT display_name, num_sequences, num_organisms, url FROM rnc_database limit 10')
    rna_columns_10 = cursor.fetchall()

# %%
pd.DataFrame(rna_columns_10, columns=['display_name', 'num_sequences', 'num_organisms', 'url'])
# Out:
#       display_name  num_sequences  num_organisms  \
# 0              ENA       12086180         814855
# 1             VEGA              0              0
# 2          GENCODE          47677              2
# 3           MGnify         135924           1929
# 4        GeneCards         517673              1
# 5              RDP           4779           2487
# 6        LNCipedia         126876              1
# 7  snoRNA Database            680             10
# 8             Rfam        1879595          14792
# 9          piRBase         200827             17
#
#                                             url
# 0            https://www.ebi.ac.uk/ena/browser/
# 1                     http://vega.sanger.ac.uk/
# 2                      http://gencodegenes.org/
# 3                                          None
# 4                    https://www.genecards.org/
# 5                       http://rdp.cme.msu.edu/
# 6                     http://www.lncipedia.org/
# ...
